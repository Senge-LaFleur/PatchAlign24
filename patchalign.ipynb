# %%
# Define your GitHub repository URL
github_repo_url = 'https://github.com/Senge-LaFleur/PatchAlign24.git' # <--- REPLACE WITH YOUR REPO URL

# Extract repository name from URL
# This assumes the URL format is like https://github.com/user/repo_name.git or https://github.com/user/repo_name
repo_name = github_repo_url.split('/')[-1]
if repo_name.endswith('.git'):
    repo_name = repo_name[:-4]

# Define your project path
# This assumes the repository is cloned into the current working directory (/content)
project_path = f'/kaggle/working/{repo_name}'

import os

# Check if the repository directory already exists
if os.path.exists(project_path):
    print(f"\nRepository '{repo_name}' already exists. Pulling latest changes...")
    # %cd "{project_path}"
    # !git pull
    # Change back to /content after git pull
    # %cd /content/
else:
    # Clone the GitHub repository
    print(f"\nCloning repository: {github_repo_url}...")
    # !git clone {github_repo_url}

# List files in your project (optional)
print(f"\nFiles in your project ({project_path}):")
# !ls -la "{project_path}"

# STAY in /content for all temporary downloads/installations
print("\nCurrent directory (should be /kaggle/working):")
# !pwd
# Out:
# Cloning repository: https://github.com/Senge-LaFleur/PatchAlign24.git...
# Cloning into 'PatchAlign24'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 85 (delta 34), reused 82 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 9.10 MiB | 23.30 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
#
# Files in your project (/kaggle/working/PatchAlign24):
# total 30284
# drwxr-xr-x 8 root root    4096 Apr 23 17:17  .
# drwxr-xr-x 4 root root    4096 Apr 23 17:17  ..
# -rw-r--r-- 1 root root     986 Apr 23 17:17  convert_nbs.py
# -rw-r--r-- 1 root root    4182 Apr 23 17:17  create_class_indices.ipynb
# -rw-r--r-- 1 root root    2544 Apr 23 17:17  create_class_indices_multitask.ipynb
# -rw-r--r-- 1 root root   76030 Apr 23 17:17 'Create Embeddings.ipynb'
# -rw-r--r-- 1 root root  232561 Apr 23 17:17  data_play_ddi.ipynb
# ...

# %%
################################################################################
# INSTALL CONDA IN TEMPORARY SPACE (/content)
################################################################################
# All these files stay in temporary memory, not in Google Drive
print("\nInstalling Miniconda in temporary space...")
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
# !rm Miniconda3-py37_4.8.2-Linux-x86_64.sh  # Clean up installer

# Verify it worked
# !conda --version

import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# Installing Miniconda in temporary space...
# PREFIX=/usr/local
# Unpacking payload ...
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
# ...

# %%
# Install the environment using the corrected environment.yml file 

# !conda  create --prefix ./patchalign  python=3.10 -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /kaggle/working/patchalign
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     ca-certificates-2026.3.19  |       h06a4308_0         126 KB
#     ld_impl_linux-64-2.44      |       h9e0c5a2_3         725 KB
#     libexpat-2.7.5             |       h7354ed3_0         122 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libgcc-15.2.0              |       h69a1729_7         806 KB
# ...

# %%
#!/kaggle/working/patchalign/bin/python -m pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0+cu113 --extra-index-url https://download.pytorch.org/whl/cu113

# %%
# !/kaggle/working/patchalign/bin/python -m pip install -r /kaggle/working/PatchAlign24/requirements.txt
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 103.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 141.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 83.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 107.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 25.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 94.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.2/809.2 kB 35.8 MB/s  0:00:00
# ...

# %%
#!/kaggle/working/skinlesion/bin/pip install opencv-python

# %%
#!/kaggle/working/skinlesion/bin/pip install "protobuf<=3.20.3"

# %%
# !/kaggle/working/skinlesion/bin/python -u /kaggle/working/FairDisCo/train_DisCoLmi.py 10 full fitzpatrick DisCoLmi
# !/kaggle/working/patchalign/bin/python -u /kaggle/working/PatchAlign24/train_PatchAlign_FitzPatrick_InDomain_Lmi.py 1 full fitzpatrick PATCHALIGN_FITZ_INDOMAIN
# Out:
# Imports complete.
# Using device: cuda
# tokenizer_config.json: 100%|██████████████████| 48.0/48.0 [00:00<00:00, 239kB/s]
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 1.66MB/s]
# vocab.txt: 232kB [00:00, 10.2MB/s]
# tokenizer.json: 466kB [00:00, 8.96MB/s]
# model.safetensors: 100%|██████████████████████| 440M/440M [00:02<00:00, 200MB/s]
# Labels loaded: 115 conditions
# Helper functions defined.
# L_mi components defined: ProjectionHead | pseudo_derm_transform | modality_invariance_loss
# train_model_lmi defined.
# SkinDatasetLmi defined.
# custom_load_lmi defined.
# Config | dataset=fitzpatrick | model=PATCHALIGN_FITZ_INDOMAIN_LMI | epochs=20 | lambda_mi=0.1
# CUDA available: True
# Domain: random_holdout
#
# Label: high
# Dataset sizes: {'train': 12809, 'val': 3203}
# config.json: 100%|█████████████████████████████| 502/502 [00:00<00:00, 1.52MB/s]
# model.safetensors: 100%|██████████████████████| 346M/346M [00:01<00:00, 209MB/s]
# ...
