# %%
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import random
import os
from PIL import Image
from skimage import io
import numpy as np
import seaborn as sns
import cv2

# %%
csv_file = 'C:\\Users\\asose\\OneDrive\\Desktop\\Senge Research\\datasets\\ddidiversedermatologyimages\\ddi_metadata.csv'#'fitzpatrick17k.csv'
df = pd.read_csv(csv_file)
# fig_folder = 'figures/'
# code_file = 'fitzpatrick17k_known_code.csv'  # this is to connect class number with class name
# code_df = pd.read_csv(code_file)

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  DDI_ID    DDI_file  skin_tone  malignant  \
# 0               0           0       1  000001.png         56       True
# 1               1           1       2  000002.png         56       True
# 2               2           2       3  000003.png         56       True
# 3               3           3       4  000004.png         56       True
# 4               4           4       5  000005.png         12       True
# ..            ...         ...     ...         ...        ...        ...
# 651           651         651     652  000652.png         34      False
# 652           652         652     653  000653.png         34      False
# 653           653         653     654  000654.png         34      False
# 654           654         654     655  000655.png         34       True
# 655           655         655     656  000656.png         34       True
#
#                              disease  high  fitzpatrick      hasher  low  \
# 0                   melanoma-in-situ     1            3  000001.png   47
# 1                   melanoma-in-situ     1            3  000002.png   47
# 2                  mycosis-fungoides     1            3  000003.png   51
# 3    squamous-cell-carcinoma-in-situ     1            3  000004.png   67
# 4               basal-cell-carcinoma     1            1  000005.png   11
# ..                               ...   ...          ...         ...  ...
# 651               pyogenic-granuloma     0            2  000652.png   59
# 652                 melanocytic-nevi     0            2  000653.png   44
# 653           acral-melanotic-macule     0            2  000654.png    4
# 654          squamous-cell-carcinoma     1            2  000655.png   66
# 655             basal-cell-carcinoma     1            2  000656.png   11
#
#      REWT_weights  RESM_weights
# 0        1.124143      0.020833
# 1        1.124143      0.020833
# 2        1.124143      0.020833
# 3        1.124143      0.020833
# 4        1.106521      0.020408
# ..            ...           ...
# 651      1.066936      0.005988
# 652      1.066936      0.005988
# 653      1.066936      0.005988
# 654      0.848941      0.013514
# 655      0.848941      0.013514
#
# [656 rows x 13 columns]

# %%
df['skin_tone'].value_counts()
# Out:
# skin_tone
# 34    241
# 12    208
# 56    207
# Name: count, dtype: int64

# %%
df['disease'].value_counts()
# Out:
# disease
# melanocytic-nevi                                119
# seborrheic-keratosis                             58
# verruca-vulgaris                                 50
# basal-cell-carcinoma                             41
# epidermal-cyst                                   35
#                                                ...
# tinea-pedis                                       1
# clear-cell-acanthoma                              1
# abscess                                           1
# blastic-plasmacytoid-dendritic-cell-neoplasm      1
# acral-melanotic-macule                            1
# Name: count, Length: 78, dtype: int64

# %%
df['malignant'].value_counts()
# Out:
# malignant
# False    485
# True     171
# Name: count, dtype: int64

# %%
fitzpatrick_list = []
high_list = []
hash_list = []
for i in range(len(df)):
    high_list.append(int(df.iloc[i]['malignant']))
    skin_tone = df.iloc[i]['skin_tone']
    hash_list.append(df.iloc[i]['DDI_file'])
    if skin_tone == 12:
        fitzpatrick_list.append(1)
    elif skin_tone == 34:
        fitzpatrick_list.append(2)
    elif skin_tone == 56:
        fitzpatrick_list.append(3)
df['high'] = high_list
df['fitzpatrick'] = fitzpatrick_list
df['hasher'] = hash_list
df["low"] = df['disease'].astype('category').cat.codes
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  DDI_ID    DDI_file  skin_tone  malignant  \
# 0               0           0       1  000001.png         56       True
# 1               1           1       2  000002.png         56       True
# 2               2           2       3  000003.png         56       True
# 3               3           3       4  000004.png         56       True
# 4               4           4       5  000005.png         12       True
# ..            ...         ...     ...         ...        ...        ...
# 651           651         651     652  000652.png         34      False
# 652           652         652     653  000653.png         34      False
# 653           653         653     654  000654.png         34      False
# 654           654         654     655  000655.png         34       True
# 655           655         655     656  000656.png         34       True
#
#                              disease  high  fitzpatrick      hasher  low  \
# 0                   melanoma-in-situ     1            3  000001.png   47
# 1                   melanoma-in-situ     1            3  000002.png   47
# 2                  mycosis-fungoides     1            3  000003.png   51
# 3    squamous-cell-carcinoma-in-situ     1            3  000004.png   67
# 4               basal-cell-carcinoma     1            1  000005.png   11
# ..                               ...   ...          ...         ...  ...
# 651               pyogenic-granuloma     0            2  000652.png   59
# 652                 melanocytic-nevi     0            2  000653.png   44
# 653           acral-melanotic-macule     0            2  000654.png    4
# 654          squamous-cell-carcinoma     1            2  000655.png   66
# 655             basal-cell-carcinoma     1            2  000656.png   11
#
#      REWT_weights  RESM_weights
# 0        1.124143      0.020833
# 1        1.124143      0.020833
# 2        1.124143      0.020833
# 3        1.124143      0.020833
# 4        1.106521      0.020408
# ..            ...           ...
# 651      1.066936      0.005988
# 652      1.066936      0.005988
# 653      1.066936      0.005988
# 654      0.848941      0.013514
# 655      0.848941      0.013514
#
# [656 rows x 13 columns]

# %%
df.to_csv('ddi_metadata_code.csv', index=False)

# %%
path = os.path.join("/bigdata/siyiplace/data/skin_lesion/ddidiversedermatologyimages/",str(df.loc[df.index[5],'hasher']))
print(path)
# Out:
# /bigdata/siyiplace/data/skin_lesion/ddidiversedermatologyimages/000006.png

# %%
'''
calculate weights for each skin type and condition
method 1 reweighting
'''
level = 'high'
total = df['fitzpatrick'].count()  # total samples
type_count = df['fitzpatrick'].value_counts().sort_index()
condition_count = df[level].value_counts().sort_index()
print(total)
print(type_count)
print(type_count[1])
print(condition_count)
weight_record = np.zeros((4, 2))
num_record = np.zeros((4, 2))
for i in range(1, 4): # skin type
    for j in range(len(condition_count)): # skin condition
        x = df.loc[(df['fitzpatrick']==i) & (df[level]==j)]
        num_record[i, j] = len(x)
        # print('joint num', len(x))
        weight = type_count[i]*condition_count[j]/(len(x)*total)
        # print('weight', weight)
        weight_record[i, j] = weight
print(weight_record)
print(num_record)
# add weights to the csv file
weight_list = []  # weight for each sample in the code_df
for k in range(total):
    row_data = df.iloc[k]
    # print(row_data)
    weight_list.append(weight_record[int(row_data['fitzpatrick']), int(row_data[level])])
    # print(weight_list)
print(len(weight_list))
df['REWT_weights'] = weight_list
# Out:
# 656
# fitzpatrick
# 1    208
# 2    241
# 3    207
# Name: count, dtype: int64
# 208
# high
# 0    485
# 1    171
# Name: count, dtype: int64
# [[0.         0.        ]
#  [0.96717288 1.10652066]
#  [1.06693625 0.84894117]
#  [0.96252301 1.12414253]]
# [[  0.   0.]
#  [159.  49.]
#  [167.  74.]
#  [159.  48.]]
# 656

# %%
'''
calculate weights for each skin type and condition
method 2 resampling   weight=1/num
'''
level = 'high'
total = df['fitzpatrick'].count()  # total samples
type_count = df['fitzpatrick'].value_counts().sort_index()
condition_count = df[level].value_counts().sort_index()
weight_record = np.zeros((4, 3))
num_record = np.zeros((4, 3))
for i in range(1, 4): # skin type
    for j in range(len(condition_count)): # skin condition
        x = df.loc[(df['fitzpatrick']==i) & (df[level]==j)]
        num_record[i, j] = len(x)
        # print('joint num', len(x))
        weight = 1/len(x)
        # print('weight', weight)
        weight_record[i, j] = weight
# print(num_record)
print(weight_record)
# add weights to the csv file
weight_list = []  # weight for each sample in the code_df
for k in range(total):
    row_data = df.iloc[k]
    # print(row_data)
    weight_list.append(weight_record[int(row_data['fitzpatrick']), int(row_data[level])])
    # print(weight_list)
print(len(weight_list))
df['RESM_weights'] = weight_list
# Out:
# [[0.         0.         0.        ]
#  [0.00628931 0.02040816 0.        ]
#  [0.00598802 0.01351351 0.        ]
#  [0.00628931 0.02083333 0.        ]]
# 656

# %%
df.to_csv(csv_file)

# %%
df.to_csv('ddi_metadata_code.csv', index=False)

# %%
# get number of samples per skin type per class  out  unknown type
np.set_printoptions(suppress=True)
label = 'high'
# fig_folder = 'figures/'
df = pd.read_csv('ddi_metadata_code.csv')
whole = np.zeros((3, len(df[label].unique())))  # whole samples

for i in range(df.shape[0]):
    row = df.iloc[i]
    type = int(row['fitzpatrick'])-1
    whole[type, row[label]] += 1

# calculate row 7. sum row 0-6        
# whole[7, :] = np.sum(whole[0:7, :], axis=0)
print(whole)
print(np.sum(whole, axis=0))
print(np.sum(whole, axis=1))
print(np.sum(whole)) 
# plot
# plt.figure(figsize=(100,8), dpi=200)
# sns.heatmap(record_array[0:7, :], annot=True, fmt=".2g", linewidths=.5)
# sns.heatmap(whole, annot=True, fmt=".2g", linewidths=.5)
# plt.xlabel('label')
# plt.ylabel('skin type')
# name = 'train__class_statistic_{}'.format(label)
# plt.title(name)
# # plt.savefig(fig_folder+name+'.jpg')
# plt.show()
# Out:
# [[159.  49.]
#  [167.  74.]
#  [159.  48.]]
# [485. 171.]
# [208. 241. 207.]
# 656.0

# %%
img_path = 'C:\\Users\\asose\\OneDrive\\Desktop\\Senge Research\\datasets\\ddidiversedermatologyimages\\000006.png'
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# img = io.imread(img_path)
img_array = np.asarray(img, dtype=np.float32)
print(img_array.shape)
plt.imshow(img)
# Out:
# (458, 323, 3)

# %%
img_path = '/images/000006.png'
img = cv2.imread(img_path)
img

# %%
import os

file_path = img_path

if os.path.exists(file_path):
    print(f"The file at '{file_path}' exists.")
else:
    print(f"The file at '{file_path}' does not exist or the path is incorrect.")
# Out:
# The file at '/images/000006.png' does not exist or the path is incorrect.

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is DE0B-CAA2
#
#  Directory of c:\Users\asose\OneDrive\Desktop\Senge Research\PatchAlign24
#
# 04/10/2026  12:34 AM    <DIR>          .
# 04/09/2026  04:23 PM    <DIR>          ..
# 04/09/2026  08:36 PM    <DIR>          .venv
# 03/31/2026  03:37 PM            76,831 Create Embeddings.ipynb
# 03/31/2026  03:37 PM             2,432 create_class_indices.ipynb
# 03/31/2026  03:37 PM             2,634 create_class_indices_multitask.ipynb
# 04/10/2026  12:43 AM           253,835 data_play_ddi.ipynb
# 04/10/2026  12:32 AM         4,357,329 data_play_fitz.ipynb
# 04/10/2026  12:34 AM            71,640 ddi_metadata_code.csv
# 04/10/2026  12:24 AM    <DIR>          Figures
# 04/10/2026  12:27 AM         4,624,016 fitapatrick17k_known_code.csv
# 04/10/2026  12:27 AM         5,279,239 fitzpatrick17k_known_code.csv
# 03/31/2026  03:37 PM            12,029 GOT.py
# 04/07/2026  06:55 PM    <DIR>          Images
# 03/31/2026  03:37 PM            12,766 Masked_GOT.py
# 03/31/2026  03:37 PM            12,870 Masked_GOT_NewSinkhorn.py
# 04/09/2026  04:18 PM         4,155,786 modality-invariance-v1.ipynb
# 04/07/2026  06:55 PM    <DIR>          Models
# 03/31/2026  03:37 PM            11,090 multi_evaluate.ipynb
# 03/31/2026  03:37 PM             4,343 README.md
# 04/09/2026  09:28 PM             3,901 requirements.txt
# 03/31/2026  03:37 PM           706,688 text_embeddings_3_large_consecutive_averaged.npy
# 03/31/2026  03:37 PM            23,315 train_ATRB.py
# 03/31/2026  03:37 PM            25,662 train_BASE.py
# 03/31/2026  03:37 PM            27,630 train_BASE_GOT.py
# 03/31/2026  03:37 PM            31,531 train_DisCo.py
# 03/31/2026  03:37 PM            33,113 train_DisCo_multitask_ddi.py
# 03/31/2026  03:37 PM            33,209 train_DisCo_multitask_fitz.py
# 03/31/2026  03:37 PM            31,522 train_Disen.py
# 03/31/2026  03:37 PM            33,393 train_GOT_DisCo.py
# 03/31/2026  03:37 PM            35,492 train_PatchAlign_DDI_InDomain.py
# 03/31/2026  03:37 PM            35,472 train_PatchAlign_FitzPatrick_InDomain.py
# 03/31/2026  03:37 PM            35,461 train_PatchAlign_FitzPatrick_OutDomain.py
# 03/31/2026  03:37 PM            25,899 train_RESM.py
# 03/31/2026  03:37 PM            23,182 train_REWT.py
# 04/10/2026  12:19 AM    <DIR>          venv
#               29 File(s)     19,982,310 bytes
#                7 Dir(s)  132,607,193,088 bytes free

# %%
ls images
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is DE0B-CAA2
#
#  Directory of c:\Users\asose\OneDrive\Desktop\Senge Research\PatchAlign24\images
#
# 04/07/2026  06:55 PM    <DIR>          .
# 04/10/2026  12:34 AM    <DIR>          ..
# 03/31/2026  03:37 PM         1,390,661 PatchAlign.png
#                1 File(s)      1,390,661 bytes
#                2 Dir(s)  132,607,016,960 bytes free
